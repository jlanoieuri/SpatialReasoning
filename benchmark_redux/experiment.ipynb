# %% [markdown]
# ### Imports and Benchmark Config

# %%
from benchmark_orchestrator import BenchmarkConfig, run_full_benchmark
from benchmark_analysis import analyze_results

config = BenchmarkConfig(
        models=['gemma3', 'gemma4:e2b', 'gemma4', 'gemma4:26b'],
        repeats=5,
        task_directory="./tasks",
        output_directory="./results",
        filter_tags=[],  # empty = run all tasks; e.g. ['2d'] to filter by tag
        think=False
    )

# %% [markdown]
# ### Run Benchmark

# %%
run_full_benchmark(config)
# Out:
# Running benchmark for model: gemma3, Repeat: 1/5
# Running benchmark for model: gemma3, Repeat: 2/5
# Running benchmark for model: gemma3, Repeat: 3/5
# Running benchmark for model: gemma3, Repeat: 4/5
# Running benchmark for model: gemma3, Repeat: 5/5
# Running benchmark for model: gemma4:e2b, Repeat: 1/5
# Running benchmark for model: gemma4:e2b, Repeat: 2/5
# Running benchmark for model: gemma4:e2b, Repeat: 3/5
# Running benchmark for model: gemma4:e2b, Repeat: 4/5
# Running benchmark for model: gemma4:e2b, Repeat: 5/5
# Running benchmark for model: gemma4, Repeat: 1/5
# Running benchmark for model: gemma4, Repeat: 2/5
# Running benchmark for model: gemma4, Repeat: 3/5
# Running benchmark for model: gemma4, Repeat: 4/5
# Running benchmark for model: gemma4, Repeat: 5/5
# Running benchmark for model: gemma4:26b, Repeat: 1/5
# Running benchmark for model: gemma4:26b, Repeat: 2/5
# Running benchmark for model: gemma4:26b, Repeat: 3/5
# ...

# %% [markdown]
# ### Analyze Results

# %%
analyze_results(
    output_dir="./results",
    save_dir="./analysis",
    filter_tags=[],  # empty = all tags; e.g. ['2d'] to restrict
)
# Out:
# Saved analysis CSV to ./analysis\analysis.csv
# Saved model accuracy plot to ./analysis\model_accuracy.png
# Saved tag accuracy plot to ./analysis\tag_accuracy.png
