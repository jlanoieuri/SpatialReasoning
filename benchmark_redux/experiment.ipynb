# %% [markdown]
# ### Imports and Benchmark Config

# %%
from benchmark_orchestrator import BenchmarkConfig, run_full_benchmark
from benchmark_analysis import analyze_results

config = BenchmarkConfig(
        models=['gemma3:latest', 'gemma4:e2b', 'gemma4:latest', 'gemma4:26b', 'qwen3:latest', 'qwen3.6:27b', 'mistral:7b'],
        model_aliases={
            'gemma3:latest': 'gemma3:4b',
            'gemma4:latest': 'gemma4:e4b',
            'qwen3:latest':  'qwen3:8b',
            },
        repeats=1,
        task_directory="./tasks",
        output_directory="./results",
        filter_tags=[],  # empty = run all tasks; e.g. ['2d'] to filter by tag
        think=False
    )

# %% [markdown]
# ### Run Benchmark

# %%
run_full_benchmark(config)
# Out:
# [VALIDATION] All checks passed.
# Running benchmark for model: gemma3:4b, Repeat: 1/1
# Running benchmark for model: gemma4:e2b, Repeat: 1/1
# Running benchmark for model: gemma4:e4b, Repeat: 1/1
# Running benchmark for model: gemma4:26b, Repeat: 1/1
# Running benchmark for model: qwen3:8b, Repeat: 1/1
# Running benchmark for model: qwen3.6:27b, Repeat: 1/1
# Running benchmark for model: mistral:7b, Repeat: 1/1
# Model: gemma3:4b, Repeat: 1, Score: 5 / 21 (23.8%)
# Model: gemma4:e2b, Repeat: 1, Score: 7 / 21 (33.3%)
# Model: gemma4:e4b, Repeat: 1, Score: 9 / 21 (42.9%)
# Model: gemma4:26b, Repeat: 1, Score: 16 / 21 (76.2%)
# Model: qwen3:8b, Repeat: 1, Score: 11 / 21 (52.4%)
# Model: qwen3.6:27b, Repeat: 1, Score: 10 / 21 (47.6%)
# Model: mistral:7b, Repeat: 1, Score: 6 / 21 (28.6%)
# Saved results to ./results\gemma34b\20260422_181647.yml
# Saved results to ./results\gemma4e2b\20260422_181647.yml
# Saved results to ./results\gemma4e4b\20260422_181647.yml
# Saved results to ./results\gemma426b\20260422_181647.yml
# Saved results to ./results\qwen38b\20260422_181647.yml
# Saved results to ./results\qwen3.627b\20260422_181647.yml
# Saved results to ./results\mistral7b\20260422_181647.yml
# Model: gemma3:4b
#   Overall Score: 5 / 21  (23.8%)
#   Tag [2d]: 3 / 10
#   Tag [rotation]: 5 / 21
#   Tag [multi_transformation]: 1 / 7
#   Tag [2d_rotation_multi]: 1 / 4
#   Tag [single_transformation]: 4 / 14
#   Tag [2d_rotation_single]: 2 / 6
#   Tag [3d]: 2 / 11
#   Tag [die]: 0 / 3
#   Tag [3d_rotations_multi_die]: 0 / 3
#   Tag [common_sense]: 2 / 8
#   Tag [3d_rotations_single_common_sense]: 2 / 8
#
# Model: gemma4:e2b
#   Overall Score: 7 / 21  (33.3%)
#   Tag [2d]: 3 / 10
#   Tag [rotation]: 7 / 21
#   Tag [multi_transformation]: 0 / 7
#   Tag [2d_rotation_multi]: 0 / 4
#   Tag [single_transformation]: 7 / 14
#   Tag [2d_rotation_single]: 3 / 6
#   Tag [3d]: 4 / 11
#   Tag [die]: 0 / 3
#   Tag [3d_rotations_multi_die]: 0 / 3
#   Tag [common_sense]: 4 / 8
#   Tag [3d_rotations_single_common_sense]: 4 / 8
#
# Model: gemma4:e4b
#   Overall Score: 9 / 21  (42.9%)
#   Tag [2d]: 6 / 10
#   Tag [rotation]: 9 / 21
#   Tag [multi_transformation]: 2 / 7
#   Tag [2d_rotation_multi]: 2 / 4
#   Tag [single_transformation]: 7 / 14
#   Tag [2d_rotation_single]: 4 / 6
#   Tag [3d]: 3 / 11
#   Tag [die]: 0 / 3
#   Tag [3d_rotations_multi_die]: 0 / 3
#   Tag [common_sense]: 3 / 8
#   Tag [3d_rotations_single_common_sense]: 3 / 8
#
# Model: gemma4:26b
#   Overall Score: 16 / 21  (76.2%)
#   Tag [2d]: 9 / 10
#   Tag [rotation]: 16 / 21
#   Tag [multi_transformation]: 4 / 7
#   Tag [2d_rotation_multi]: 3 / 4
#   Tag [single_transformation]: 12 / 14
#   Tag [2d_rotation_single]: 6 / 6
#   Tag [3d]: 7 / 11
#   Tag [die]: 1 / 3
#   Tag [3d_rotations_multi_die]: 1 / 3
#   Tag [common_sense]: 6 / 8
#   Tag [3d_rotations_single_common_sense]: 6 / 8
#
# Model: qwen3:8b
#   Overall Score: 11 / 21  (52.4%)
#   Tag [2d]: 5 / 10
#   Tag [rotation]: 11 / 21
#   Tag [multi_transformation]: 1 / 7
#   Tag [2d_rotation_multi]: 1 / 4
#   Tag [single_transformation]: 10 / 14
#   Tag [2d_rotation_single]: 4 / 6
#   Tag [3d]: 6 / 11
#   Tag [die]: 0 / 3
#   Tag [3d_rotations_multi_die]: 0 / 3
#   Tag [common_sense]: 6 / 8
#   Tag [3d_rotations_single_common_sense]: 6 / 8
#
# Model: qwen3.6:27b
#   Overall Score: 10 / 21  (47.6%)
#   Tag [2d]: 5 / 10
#   Tag [rotation]: 10 / 21
#   Tag [multi_transformation]: 1 / 7
#   Tag [2d_rotation_multi]: 1 / 4
#   Tag [single_transformation]: 9 / 14
#   Tag [2d_rotation_single]: 4 / 6
#   Tag [3d]: 5 / 11
#   Tag [die]: 0 / 3
#   Tag [3d_rotations_multi_die]: 0 / 3
#   Tag [common_sense]: 5 / 8
#   Tag [3d_rotations_single_common_sense]: 5 / 8
#
# Model: mistral:7b
#   Overall Score: 6 / 21  (28.6%)
#   Tag [2d]: 1 / 10
#   Tag [rotation]: 6 / 21
#   Tag [multi_transformation]: 0 / 7
#   Tag [2d_rotation_multi]: 0 / 4
#   Tag [single_transformation]: 6 / 14
#   Tag [2d_rotation_single]: 1 / 6
#   Tag [3d]: 5 / 11
#   Tag [die]: 0 / 3
#   Tag [3d_rotations_multi_die]: 0 / 3
#   Tag [common_sense]: 5 / 8
#   Tag [3d_rotations_single_common_sense]: 5 / 8

# %% [markdown]
# ### Analyze Results

# %%
# Perform Categorical Analysis (Per-Catgeory accuracy/Total Average Accuracy)
analyze_results(
    output_dir="./results",
    save_dir="./analysis/categorical_analysis",
    filter_tags=['2d_rotation_single', '2d_rotation_multi', '3d_rotations_multi_die', '3d_rotations_single_common_sense'],  # empty = all tags; e.g. ['2d'] to restrict
    tag_plot_title="Per-Category Accuracy by Model",
    plot_overall_accuracy=True
)

from IPython.display import Image

# Display ./analysis/categorical_analysis/model_accuracy.png
Image("./analysis/categorical_analysis/model_accuracy.png")
# Out:
# Saved analysis CSV to ./analysis/categorical_analysis\analysis.csv
# Saved model accuracy plot to ./analysis/categorical_analysis\model_accuracy.png
# Saved tag accuracy plot to ./analysis/categorical_analysis\tag_accuracy.png

# %%
# Display ./analysis/categorical_analysis/model_accuracy.png
Image("./analysis/categorical_analysis/tag_accuracy.png")

# %%
# Perform Tag-Level Analysis (Per-Tag accuracy)
analyze_results(
    output_dir="./results",
    save_dir="./analysis/tag_level_analysis",
    filter_tags=[],  # empty = all tags; e.g. ['2d'] to restrict
    tag_plot_title="Per-Tag Accuracy by Model",
    plot_overall_accuracy=False
)

# Display ./analysis/tag_level_analysis/tag_accuracy.png
Image("./analysis/tag_level_analysis/tag_accuracy.png")
# Out:
# Saved analysis CSV to ./analysis/tag_level_analysis\analysis.csv
# Saved tag accuracy plot to ./analysis/tag_level_analysis\tag_accuracy.png
